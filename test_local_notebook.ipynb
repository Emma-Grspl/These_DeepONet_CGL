# %%
from src/plot/plot_snapshot import plot_temporal_snapshots
# Out:
#   Cell In[2], line 1
#     from src/plot/plot_snapshot import plot_temporal_snapshots
#             ^
# SyntaxError: invalid syntax
